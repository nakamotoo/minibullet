# %%
import roboverse
import numpy as np
from PIL import Image
def _process_image(obs):
    obs = (obs * 255).astype(np.uint8)
    obs = np.reshape(obs, (3, 128, 128))
    return np.transpose(obs, (1, 2, 0))

# %%
# env_name = 'PutBallintoBowlDiverse-v0'
env_name = 'PutBallintoBowlTwoDistractors-v0'
env = roboverse.make(env_name, transpose_image=True)
# Out:
# pybullet build time: May 22 2023 10:54:04
# /nfs/nfs2/users/mitsuhiko/miniconda/envs/jax_tpu/lib/python3.10/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Container config: {'container_position_low': (0.5, 0.26, -0.3), 'container_position_high': (0.7, 0.26, -0.3), 'container_position_default': (0.5, 0.26, -0.3), 'container_position_z': -0.35, 'place_success_height_threshold': -0.32, 'place_success_radius_threshold': 0.05, 'container_orientation': (0, 0, 0.707107, 0.707107), 'container_scale': 0.07, 'min_distance_from_object': 0.11}
# ('ball', 'jar', 'beer_bottle')
# Container position: [ 0.69447068  0.26       -0.35      ]
# LEFT: True
# Container position: [ 0.68425651  0.26       -0.35      ]
# LEFT: True

# %%
obs = env.reset()
obs  = _process_image(obs["image"])
obs = Image.fromarray(obs)
obs
# Out:
# Container position: [ 0.64333263  0.26       -0.35      ]
# LEFT: True
# <PIL.Image.Image image mode=RGB size=128x128>
